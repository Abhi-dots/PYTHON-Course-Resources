# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel("sales.xlsx")

# %%
# head() - it shows first five rows from data
# tail() - it shows last five rows from data

# %%
df.head()
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 1     1002 2025-01-02       C102        Priya    Chennai  Mobile  Electronics
# 2     1003 2025-01-02       C103        Arjun  Bangalore   Shoes      Fashion
# 3     1004 2025-01-03       C101        Rahul  Hyderabad   Watch  Accessories
# 4     1005 2025-01-03       C104        Sneha     Mumbai  Laptop  Electronics
#
#    Quantity  Price  Discount PaymentMode SalesPerson
# 0         1  50000      5000         UPI        Ravi
# 1         2  20000      1000        Card      Suresh
# 2         3   3000       300        Cash        Ravi
# 3         1   5000       500         UPI       Kiran
# 4         1  55000      2000        Card        Ravi

# %%
df.tail()
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City     Product  \
# 10     1011 2025-01-06       C110       Rakesh    Chennai       Watch
# 11     1012 2025-01-07       C111        Divya  Bangalore      Mobile
# 12     1013 2025-01-08       C112        Varun  Hyderabad       Shoes
# 13     1014 2025-01-08       C113        Pooja    Chennai      Laptop
# 14     1015 2025-01-09       C114         Ajay     Mumbai  Headphones
#
#        Category  Quantity  Price  Discount PaymentMode SalesPerson
# 10  Accessories         2   4500       300         UPI        Ravi
# 11  Electronics         1  22000      1000        Card       Kiran
# 12      Fashion         5   2800       400        Cash        Ravi
# 13  Electronics         1  52000      2500         UPI      Suresh
# 14  Electronics         3   2700       300        Card        Ravi

# %%
# how many records are there in data?
# which columns are available?
# Are there any missing values?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       15 non-null     int64
#  1   OrderDate     15 non-null     datetime64[ns]
#  2   CustomerID    15 non-null     object
#  3   CustomerName  15 non-null     object
#  4   City          15 non-null     object
#  5   Product       15 non-null     object
#  6   Category      15 non-null     object
#  7   Quantity      15 non-null     int64
#  8   Price         15 non-null     int64
#  9   Discount      15 non-null     int64
#  10  PaymentMode   15 non-null     object
#  11  SalesPerson   15 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 1.5+ KB

# %%
df.shape
# Out:
# (15, 12)

# %%
df["CustomerName"]
# Out:
# 0      Rahul
# 1      Priya
# 2      Arjun
# 3      Rahul
# 4      Sneha
# 5       Teja
# 6        Ram
# 7     Anjali
# 8      Mohan
# 9      Kavya
# 10    Rakesh
# 11     Divya
# 12     Varun
# 13     Pooja
# 14      Ajay
# Name: CustomerName, dtype: object

# %%
df[["CustomerName", "City"]]
# Out:
#    CustomerName       City
# 0         Rahul  Hyderabad
# 1         Priya    Chennai
# 2         Arjun  Bangalore
# 3         Rahul  Hyderabad
# 4         Sneha     Mumbai
# 5          Teja  Hyderabad
# 6           Ram    Chennai
# 7        Anjali  Bangalore
# 8         Mohan  Hyderabad
# 9         Kavya     Mumbai
# 10       Rakesh    Chennai
# 11        Divya  Bangalore
# 12        Varun  Hyderabad
# 13        Pooja    Chennai
# 14         Ajay     Mumbai

# %%
# data filtering

# %%
df[df["Product"] == "Mobile"]
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City Product  \
# 1      1002 2025-01-02       C102        Priya    Chennai  Mobile
# 6      1007 2025-01-04       C106          Ram    Chennai  Mobile
# 11     1012 2025-01-07       C111        Divya  Bangalore  Mobile
#
#        Category  Quantity  Price  Discount PaymentMode SalesPerson
# 1   Electronics         2  20000      1000        Card      Suresh
# 6   Electronics         1  25000      1500         UPI        Ravi
# 11  Electronics         1  22000      1000        Card       Kiran

# %%
df["Product"] == "Mobile"
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# Name: Product, dtype: bool

# %%
df[(df["City"] == "Hyderabad") & (df["Price"] > 20000)]
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
#
#    Quantity  Price  Discount PaymentMode SalesPerson
# 0         1  50000      5000         UPI        Ravi

# %%
df[(df["City"] == "Hyderabad") | (df["Price"] > 20000)]
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City Product  \
# 0      1001 2025-01-01       C101        Rahul  Hyderabad  Laptop
# 3      1004 2025-01-03       C101        Rahul  Hyderabad   Watch
# 4      1005 2025-01-03       C104        Sneha     Mumbai  Laptop
# 5      1006 2025-01-04       C105         Teja  Hyderabad  TShirt
# 6      1007 2025-01-04       C106          Ram    Chennai  Mobile
# 8      1009 2025-01-05       C108        Mohan  Hyderabad   Shoes
# 9      1010 2025-01-06       C109        Kavya     Mumbai  Laptop
# 11     1012 2025-01-07       C111        Divya  Bangalore  Mobile
# 12     1013 2025-01-08       C112        Varun  Hyderabad   Shoes
# 13     1014 2025-01-08       C113        Pooja    Chennai  Laptop
#
#        Category  Quantity  Price  Discount PaymentMode SalesPerson
# 0   Electronics         1  50000      5000         UPI        Ravi
# 3   Accessories         1   5000       500         UPI       Kiran
# ...

# %%
df.head(3)
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 1     1002 2025-01-02       C102        Priya    Chennai  Mobile  Electronics
# 2     1003 2025-01-02       C103        Arjun  Bangalore   Shoes      Fashion
#
#    Quantity  Price  Discount PaymentMode SalesPerson
# 0         1  50000      5000         UPI        Ravi
# 1         2  20000      1000        Card      Suresh
# 2         3   3000       300        Cash        Ravi

# %%
# revenue = quantity * price - discount

# %%
df["Revenue"] = (df["Quantity"] * df["Price"]) - df["Discount"]

# %%
df.head(2)
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 1     1002 2025-01-02       C102        Priya    Chennai  Mobile  Electronics
#
#    Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0         1  50000      5000         UPI        Ravi    45000
# 1         2  20000      1000        Card      Suresh    39000

# %%
# sort_values

# %%
df.head()
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 1     1002 2025-01-02       C102        Priya    Chennai  Mobile  Electronics
# 2     1003 2025-01-02       C103        Arjun  Bangalore   Shoes      Fashion
# 3     1004 2025-01-03       C101        Rahul  Hyderabad   Watch  Accessories
# 4     1005 2025-01-03       C104        Sneha     Mumbai  Laptop  Electronics
#
#    Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0         1  50000      5000         UPI        Ravi    45000
# 1         2  20000      1000        Card      Suresh    39000
# 2         3   3000       300        Cash        Ravi     8700
# 3         1   5000       500         UPI       Kiran     4500
# 4         1  55000      2000        Card        Ravi    53000

# %%
df.sort_values(by = "Price", ascending = True)
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City     Product  \
# 5      1006 2025-01-04       C105         Teja  Hyderabad      TShirt
# 7      1008 2025-01-05       C107       Anjali  Bangalore  Headphones
# 14     1015 2025-01-09       C114         Ajay     Mumbai  Headphones
# 12     1013 2025-01-08       C112        Varun  Hyderabad       Shoes
# 2      1003 2025-01-02       C103        Arjun  Bangalore       Shoes
# 8      1009 2025-01-05       C108        Mohan  Hyderabad       Shoes
# 10     1011 2025-01-06       C110       Rakesh    Chennai       Watch
# 3      1004 2025-01-03       C101        Rahul  Hyderabad       Watch
# 1      1002 2025-01-02       C102        Priya    Chennai      Mobile
# 11     1012 2025-01-07       C111        Divya  Bangalore      Mobile
# 6      1007 2025-01-04       C106          Ram    Chennai      Mobile
# 0      1001 2025-01-01       C101        Rahul  Hyderabad      Laptop
# ...

# %%
df.sort_values(by = "Price", ascending = False)
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City     Product  \
# 9      1010 2025-01-06       C109        Kavya     Mumbai      Laptop
# 4      1005 2025-01-03       C104        Sneha     Mumbai      Laptop
# 13     1014 2025-01-08       C113        Pooja    Chennai      Laptop
# 0      1001 2025-01-01       C101        Rahul  Hyderabad      Laptop
# 6      1007 2025-01-04       C106          Ram    Chennai      Mobile
# 11     1012 2025-01-07       C111        Divya  Bangalore      Mobile
# 1      1002 2025-01-02       C102        Priya    Chennai      Mobile
# 3      1004 2025-01-03       C101        Rahul  Hyderabad       Watch
# 10     1011 2025-01-06       C110       Rakesh    Chennai       Watch
# 8      1009 2025-01-05       C108        Mohan  Hyderabad       Shoes
# 2      1003 2025-01-02       C103        Arjun  Bangalore       Shoes
# 12     1013 2025-01-08       C112        Varun  Hyderabad       Shoes
# ...

# %%
#unique()

# %%
df["City"].unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Bangalore', 'Mumbai'], dtype=object)

# %%
#nunique()

# %%
df["City"].nunique()
# Out:
# 4

# %%
#value_counts()

# %%
df["City"].value_counts()
# Out:
# City
# Hyderabad    5
# Chennai      4
# Bangalore    3
# Mumbai       3
# Name: count, dtype: int64

# %%
#isnull()

# %%
df.isnull().sum()
# Out:
# OrderID         0
# OrderDate       0
# CustomerID      0
# CustomerName    0
# City            0
# Product         0
# Category        0
# Quantity        0
# Price           0
# Discount        0
# PaymentMode     0
# SalesPerson     0
# Revenue         0
# dtype: int64

# %%
#notnull()

# %%
df.notnull().sum()
# Out:
# OrderID         15
# OrderDate       15
# CustomerID      15
# CustomerName    15
# City            15
# Product         15
# Category        15
# Quantity        15
# Price           15
# Discount        15
# PaymentMode     15
# SalesPerson     15
# Revenue         15
# dtype: int64

# %%
# fillna()

# %%
df["City"] = df["City"].fillna("Unknown")

# %%
df["Price"] = df["Price"].fillna(df["Price"].mean())

# %%
# dropna()

# %%
df.dropna(axis = 0)
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City     Product  \
# 0      1001 2025-01-01       C101        Rahul  Hyderabad      Laptop
# 1      1002 2025-01-02       C102        Priya    Chennai      Mobile
# 2      1003 2025-01-02       C103        Arjun  Bangalore       Shoes
# 3      1004 2025-01-03       C101        Rahul  Hyderabad       Watch
# 4      1005 2025-01-03       C104        Sneha     Mumbai      Laptop
# 5      1006 2025-01-04       C105         Teja  Hyderabad      TShirt
# 6      1007 2025-01-04       C106          Ram    Chennai      Mobile
# 7      1008 2025-01-05       C107       Anjali  Bangalore  Headphones
# 8      1009 2025-01-05       C108        Mohan  Hyderabad       Shoes
# 9      1010 2025-01-06       C109        Kavya     Mumbai      Laptop
# 10     1011 2025-01-06       C110       Rakesh    Chennai       Watch
# 11     1012 2025-01-07       C111        Divya  Bangalore      Mobile
# ...

# %%
# duplicated()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
# drop_duplicates()

# %%
df.drop_duplicates()
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City     Product  \
# 0      1001 2025-01-01       C101        Rahul  Hyderabad      Laptop
# 1      1002 2025-01-02       C102        Priya    Chennai      Mobile
# 2      1003 2025-01-02       C103        Arjun  Bangalore       Shoes
# 3      1004 2025-01-03       C101        Rahul  Hyderabad       Watch
# 4      1005 2025-01-03       C104        Sneha     Mumbai      Laptop
# 5      1006 2025-01-04       C105         Teja  Hyderabad      TShirt
# 6      1007 2025-01-04       C106          Ram    Chennai      Mobile
# 7      1008 2025-01-05       C107       Anjali  Bangalore  Headphones
# 8      1009 2025-01-05       C108        Mohan  Hyderabad       Shoes
# 9      1010 2025-01-06       C109        Kavya     Mumbai      Laptop
# 10     1011 2025-01-06       C110       Rakesh    Chennai       Watch
# 11     1012 2025-01-07       C111        Divya  Bangalore      Mobile
# ...

# %%
# string functions

# %%
# upper()

# %%
df["CustomerName"].str.upper()
# Out:
# 0      RAHUL
# 1      PRIYA
# 2      ARJUN
# 3      RAHUL
# 4      SNEHA
# 5       TEJA
# 6        RAM
# 7     ANJALI
# 8      MOHAN
# 9      KAVYA
# 10    RAKESH
# 11     DIVYA
# 12     VARUN
# 13     POOJA
# 14      AJAY
# Name: CustomerName, dtype: object

# %%
# lower()

# %%
# gnanesh elisetty
# title()

# %%
# Gnanesh Elisetty

# %%
# len()

# %%
df["CustomerName"].str.len()
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     4
# 6     3
# 7     6
# 8     5
# 9     5
# 10    6
# 11    5
# 12    5
# 13    5
# 14    4
# Name: CustomerName, dtype: int64

# %%
# contains()

# %%
df[df["CustomerName"].str.contains("h")]
# Out:
#     OrderID  OrderDate CustomerID CustomerName       City Product  \
# 0      1001 2025-01-01       C101        Rahul  Hyderabad  Laptop
# 3      1004 2025-01-03       C101        Rahul  Hyderabad   Watch
# 4      1005 2025-01-03       C104        Sneha     Mumbai  Laptop
# 8      1009 2025-01-05       C108        Mohan  Hyderabad   Shoes
# 10     1011 2025-01-06       C110       Rakesh    Chennai   Watch
#
#        Category  Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0   Electronics         1  50000      5000         UPI        Ravi    45000
# 3   Accessories         1   5000       500         UPI       Kiran     4500
# 4   Electronics         1  55000      2000        Card        Ravi    53000
# 8       Fashion         2   3500       500        Cash        Ravi     6500
# 10  Accessories         2   4500       300         UPI        Ravi     8700

# %%
# replace()

# %%
df["Product"].str.replace("Laptop", "Dell Laptop")
# Out:
# 0     Dell Laptop
# 1          Mobile
# 2           Shoes
# 3           Watch
# 4     Dell Laptop
# 5          TShirt
# 6          Mobile
# 7      Headphones
# 8           Shoes
# 9     Dell Laptop
# 10          Watch
# 11         Mobile
# 12          Shoes
# 13    Dell Laptop
# 14     Headphones
# Name: Product, dtype: object

# %%
# loc[] and iloc[]

# %%
# loc[]

# %%
df.loc[[0, 5]]
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 5     1006 2025-01-04       C105         Teja  Hyderabad  TShirt      Fashion
#
#    Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0         1  50000      5000         UPI        Ravi    45000
# 5         4    800       100        Cash      Suresh     3100

# %%
df.loc[0 : 5]
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 1     1002 2025-01-02       C102        Priya    Chennai  Mobile  Electronics
# 2     1003 2025-01-02       C103        Arjun  Bangalore   Shoes      Fashion
# 3     1004 2025-01-03       C101        Rahul  Hyderabad   Watch  Accessories
# 4     1005 2025-01-03       C104        Sneha     Mumbai  Laptop  Electronics
# 5     1006 2025-01-04       C105         Teja  Hyderabad  TShirt      Fashion
#
#    Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0         1  50000      5000         UPI        Ravi    45000
# 1         2  20000      1000        Card      Suresh    39000
# 2         3   3000       300        Cash        Ravi     8700
# 3         1   5000       500         UPI       Kiran     4500
# 4         1  55000      2000        Card        Ravi    53000
# ...

# %%
df.loc[3, "CustomerName"]
# Out:
# 'Rahul'

# %%
#iloc[]

# %%
df.iloc[[0, 2, 4]]
# Out:
#    OrderID  OrderDate CustomerID CustomerName       City Product     Category  \
# 0     1001 2025-01-01       C101        Rahul  Hyderabad  Laptop  Electronics
# 2     1003 2025-01-02       C103        Arjun  Bangalore   Shoes      Fashion
# 4     1005 2025-01-03       C104        Sneha     Mumbai  Laptop  Electronics
#
#    Quantity  Price  Discount PaymentMode SalesPerson  Revenue
# 0         1  50000      5000         UPI        Ravi    45000
# 2         3   3000       300        Cash        Ravi     8700
# 4         1  55000      2000        Card        Ravi    53000

# %%
df.iloc[2:4, 2:4]
# Out:
#   CustomerID CustomerName
# 2       C103        Arjun
# 3       C101        Rahul

# %%
# groupby()

# %%
df["Revenue"].sum()
# Out:
# np.int64(345700)

# %%
df.groupby("City")["Revenue"].sum()
# Out:
# City
# Bangalore     34500
# Chennai      120700
# Hyderabad     72700
# Mumbai       117800
# Name: Revenue, dtype: int64

# %%
df.groupby(["City", "Product"])["Revenue"].sum()
# Out:
# City       Product
# Bangalore  Headphones      4800
#            Mobile         21000
#            Shoes           8700
# Chennai    Laptop         49500
#            Mobile         62500
#            Watch           8700
# Hyderabad  Laptop         45000
#            Shoes          20100
#            TShirt          3100
#            Watch           4500
# Mumbai     Headphones      7800
#            Laptop        110000
# Name: Revenue, dtype: int64

# %%
# aggregation -- agg()

# %%
df.groupby("City")["Revenue"].agg(["sum", "min", "max", "mean"])
# Out:
#               sum   min    max          mean
# City
# Bangalore   34500  4800  21000  11500.000000
# Chennai    120700  8700  49500  30175.000000
# Hyderabad   72700  3100  45000  14540.000000
# Mumbai     117800  7800  57000  39266.666667

# %%
# pivot_table()

# %%
pd.pivot_table(df, values = "Revenue", index = "City", aggfunc = "sum")
# Out:
#            Revenue
# City
# Bangalore    34500
# Chennai     120700
# Hyderabad    72700
# Mumbai      117800
